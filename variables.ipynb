# %%
#type casting / type conversion
#two types of type casting:
#1. implicit type casting
#2. explicit type casting

# %%
#implicit type casting
a= 10
b = 3.5
c=a*b
print (a,type(a))
print (b,type(b))
print (c,int(c),type(c))
# Out:
# 10 <class 'int'>
# 3.5 <class 'float'>
# 35.0 35 <class 'float'>

# %%
a= 10
b = 3.5
c=int (c)
print (a,type(a))
print (b,type(b))
print (c,int(c),type(c))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 a= 10
#       2 b = 3.5
# ----> 3 c=int (c)
#       4 print (a,type(a))
#       5 print (b,type(b))
#       6 print (c,int(c),type(c))
#
# NameError: name 'c' is not defined

# %%
age = 20

# %%
age_str=str(age)
print (age_str,type(age_str))
# Out:
# 20 <class 'str'>

# %%
x = "123.56"
print (x, type(x))

y = float(x)
print (y, type(y))
# Out:
# 123.56 <class 'str'>
# 123.56 <class 'float'>

# %%
age = int(input("Enter your age: "))
print (age, type(age))
# Out:
# 19 <class 'int'>

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

sum = num1 + num2
difference = num1 - num2
product = num1 * num2
quotient = num1 / num2

print("Sum:", sum)
print("Difference:", difference)
print("Product:", product)
print("Quotient:", quotient)
# Out:
# Sum: 4
# Difference: 0
# Product: 4
# Quotient: 1.0

# %%
a=10
b=5
add_result = a + b
sub_result = a - b
mult_result = a * b
div_result = a / b
floor_div_result = a // b
modulus_result = a % b
exponent_result = a ** b
print(add_result)
print (sub_result)
print (mult_result)
print (div_result)
print (floor_div_result)
print (modulus_result)
print (exponent_result)
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
print("Hello " *7)
# Out:
# Hello Hello Hello Hello Hello Hello Hello

# %%
x=10
y=3
print (x>y)
print (x<y)
print (x==y)
print (x!=y)
# Out:
# True
# False
# False
# True

# %%
a=2
b=7
print (a&b)
print(a|b)
print (a^b)
print(~a)
# Out:
# 2
# 7
# 5
# -3

# %%
x=5
print(x)
x+=5
print(x)
x-=5
print(x)
x*=5
print(x)
x**=5   
print(x)
x/=5
print(x)
x//=5
print(x)
x = int(x)
x ^= 5
print(x)
x>>=5
print(x)
# Out:
# 5
# 10
# 5
# 25
# 9765625
# 1953125.0
# 390625.0
# 390628
# 12207

# %%
a= 10
b=10
c=15

print (a is b)
print (a == b)

print (id(a),id(b))
# Out:
# True
# True
# 140717586621848 140717586621848

# %%
import copy 
x=10
y=copy.copy(x)
print(id(x),id(y))
# Out:
# 140717586621848 140717586621848

# %%
print (6 in [1,2,3,4,5,6,7])
# Out:
# True
