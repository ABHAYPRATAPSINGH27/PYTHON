# %%
# WAP for binary search and linear search in python

# %%
# Calculate frequency of each character using function in Python

# %%
# WAP to count vowels in a string using functions in Python

string = ["Enter your Name "]
count_vowels =

# %%
# Find the largest value in a list using functions in Python

number = [1,2,3,4,5,6,7,8,9]
largest_number = max(number)
print(largest_number)
# Out:
# 9

# %%
# WAP to find the second largest number in the list

# %%
# WAP to remove duplicate elements in a list

# %%
# check whether 2 stings are anagrams
